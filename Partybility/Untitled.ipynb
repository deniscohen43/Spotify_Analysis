# %%
# %matplotlib inline
#Dependcies and Setup
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
#Files to Load
spotify_data_load = "../Resources/spotify_new.csv"

#Read Data
spotify_data = pd.read_csv(spotify_data_load, encoding="ISO-8859-1")
spotify_data.head()
# Out:
#   genre     artist_name                                  track_name  \
# 0   R&B   Mary J. Blige                  Be Without You - Kendu Mix
# 1   R&B         Rihanna                                   Desperado
# 2   R&B       Yung Bleu  Ice On My Baby (feat. Kevin Gates) - Remix
# 3   R&B        Surfaces                   Heaven Falls / Fall on Me
# 4   R&B  Olivia O'Brien                                 Love Myself
#
#                  track_id  popularity  acousticness  danceability  \
# 0  2YegxR5As7BeQuVp2U6pek          65        0.0830         0.724
# 1  6KFaHC9G178beAp7P0Vi5S          63        0.3230         0.685
# 2  6muW8cSjJ3rusKJ0vH5olw          62        0.0675         0.762
# 3  7yHqOZfsXYlicyoMt62yC6          61        0.3600         0.563
# 4  4XzgjxGKqULifVf7mnDIQK          68        0.5960         0.653
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0       246333   0.689          0.000000   D    0.3040    -5.922  Minor
# ...

# %%
# Read in 3 needed columns into data frame
slapability_data = spotify_data[["genre", "danceability", "energy", "loudness"]]

# %%
grouped_genre = slapability_data.groupby(['genre'])
grouped_genre
grouped_genre.head(10)
# Out:
#               genre  danceability  energy  loudness
# 0               R&B         0.724  0.6890    -5.922
# 1               R&B         0.685  0.6100    -5.221
# 2               R&B         0.762  0.5200    -5.237
# 3               R&B         0.563  0.3660    -6.896
# 4               R&B         0.653  0.6210    -5.721
# 5               R&B         0.510  0.3310   -13.073
# 6               R&B         0.670  0.6490    -7.426
# 7               R&B         0.377  0.2550   -11.165
# 8               R&B         0.523  0.5070    -6.448
# 9               R&B         0.761  0.6390    -7.577
# 144     Alternative         0.552  0.6500    -7.199
# 145     Alternative         0.515  0.4790    -7.458
# 146     Alternative         0.672  0.5880    -9.573
# 147     Alternative         0.803  0.5990    -5.169
# 148     Alternative         0.900  0.3160    -8.797
# 149     Alternative         0.525  0.7740    -4.532
# 150     Alternative         0.731  0.8610    -5.881
# ...
