# %%
# %matplotlib inline
#Dependcies and Setup
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np

# %%
#Files to Load
spotify_data_load = "../Resources/spotify_new.csv"

#Read Data
spotify_data = pd.read_csv(spotify_data_load, encoding="ISO-8859-1")
spotify_data.head()
# Out:
#   genre     artist_name                                  track_name  \
# 0   R&B   Mary J. Blige                  Be Without You - Kendu Mix
# 1   R&B         Rihanna                                   Desperado
# 2   R&B       Yung Bleu  Ice On My Baby (feat. Kevin Gates) - Remix
# 3   R&B        Surfaces                   Heaven Falls / Fall on Me
# 4   R&B  Olivia O'Brien                                 Love Myself
#
#                  track_id  popularity  acousticness  danceability  \
# 0  2YegxR5As7BeQuVp2U6pek          65        0.0830         0.724
# 1  6KFaHC9G178beAp7P0Vi5S          63        0.3230         0.685
# 2  6muW8cSjJ3rusKJ0vH5olw          62        0.0675         0.762
# 3  7yHqOZfsXYlicyoMt62yC6          61        0.3600         0.563
# 4  4XzgjxGKqULifVf7mnDIQK          68        0.5960         0.653
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0       246333   0.689          0.000000   D    0.3040    -5.922  Minor
# 1       186467   0.610          0.000000   C    0.1020    -5.221  Minor
# 2       199520   0.520          0.000004   F    0.1140    -5.237  Minor
# 3       240597   0.366          0.002430   B    0.0955    -6.896  Minor
# 4       213947   0.621          0.000000   B    0.0811    -5.721  Minor
#
#    speechiness    tempo time_signature  valence
# 0       0.1350  146.496            4/4   0.6930
# 1       0.0439   94.384            3/4   0.3230
# 2       0.0959   75.047            4/4   0.0862
# 3       0.1210   85.352            4/4   0.7680
# 4       0.0409  100.006            4/4   0.4660

# %%
# Read in 6 needed columns into data frame
slapability_data = spotify_data[["genre", "popularity", "danceability", "energy", "loudness","tempo"]]
slapability_data
# Out:
#        genre  popularity  danceability  energy  loudness    tempo
# 0        R&B          65         0.724   0.689    -5.922  146.496
# 1        R&B          63         0.685   0.610    -5.221   94.384
# 2        R&B          62         0.762   0.520    -5.237   75.047
# 3        R&B          61         0.563   0.366    -6.896   85.352
# 4        R&B          68         0.653   0.621    -5.721  100.006
# 5        R&B          61         0.510   0.331   -13.073  124.657
# 6        R&B          64         0.670   0.649    -7.426  147.935
# 7        R&B          66         0.377   0.255   -11.165  125.004
# 8        R&B          60         0.523   0.507    -6.448  140.368
# 9        R&B          69         0.761   0.639    -7.577  164.088
# 10       R&B          71         0.501   0.378    -9.370  119.987
# 11       R&B          69         0.639   0.659    -7.273  136.801
# 12       R&B          76         0.845   0.709    -4.547   98.062
# 13       R&B          61         0.584   0.687    -7.176  129.902
# 14       R&B          66         0.741   0.345   -11.310  120.015
# 15       R&B          65         0.751   0.766    -3.594  109.897
# 16       R&B          61         0.791   0.494    -8.705  146.003
# 17       R&B          62         0.703   0.586    -4.587  149.736
# 18       R&B          65         0.457   0.337   -10.825   66.933
# 19       R&B          65         0.759   0.342    -9.044   99.995
# 20       R&B          63         0.546   0.698    -4.678   72.417
# 21       R&B          68         0.690   0.502    -7.077   86.185
# 22       R&B          67         0.733   0.650    -3.539  110.003
# 23       R&B          65         0.259   0.536   -10.309  143.948
# 24       R&B          65         0.752   0.883    -4.450  122.026
# 25       R&B          70         0.721   0.881    -2.528  127.759
# 26       R&B          72         0.637   0.730    -5.380   93.867
# 27       R&B          66         0.612   0.548    -6.710   84.991
# 28       R&B          68         0.811   0.458    -9.688   92.940
# 29       R&B          67         0.344   0.537    -8.215   82.878
# ...      ...         ...           ...     ...       ...      ...
# 164215  Soul          37         0.646   0.827    -3.651  103.044
# 164216  Soul          40         0.711   0.697    -7.788   99.987
# 164217  Soul          41         0.888   0.527    -8.293  123.028
# 164218  Soul          41         0.767   0.494    -5.349   96.003
# 164219  Soul          39         0.597   0.859    -6.343  172.968
# 164220  Soul          32         0.550   0.618   -11.138  110.738
# 164221  Soul          35         0.600   0.395    -6.868  143.827
# 164222  Soul          46         0.505   0.463   -10.652  105.660
# 164223  Soul          41         0.563   0.620    -6.292   82.059
# 164224  Soul          40         0.875   0.830    -4.222  114.024
# 164225  Soul          40         0.380   0.160   -17.717  179.284
# 164226  Soul          37         0.752   0.584    -8.388  118.054
# 164227  Soul          45         0.502   0.299    -8.956  116.845
# 164228  Soul          41         0.754   0.479    -8.305  129.971
# 164229  Soul          42         0.837   0.541    -5.068  103.971
# 164230  Soul          42         0.764   0.448   -14.135  116.096
# 164231  Soul          41         0.764   0.757    -7.049  115.016
# 164232  Soul          38         0.630   0.655    -6.708  102.009
# 164233  Soul          39         0.659   0.644    -4.510  143.887
# 164234  Soul          39         0.611   0.493    -9.297  115.920
# 164235  Soul          42         0.394   0.346   -13.617   90.831
# 164236  Soul          39         0.736   0.701    -4.345   99.991
# 164237  Soul          43         0.802   0.516    -9.014  175.666
# 164238  Soul          43         0.294   0.739    -7.167  176.402
# 164239  Soul          32         0.423   0.337   -13.092   80.023
# 164240  Soul          39         0.687   0.714   -10.626  115.542
# 164241  Soul          38         0.785   0.683    -6.944  113.830
# 164242  Soul          47         0.517   0.419    -8.282   84.135
# 164243  Soul          44         0.745   0.704    -7.137  100.031
# 164244  Soul          35         0.758   0.470    -6.708  113.897
#
# [164245 rows x 6 columns]

# %%
#Group by genre
grouped_genre = slapability_data.groupby(['genre'])
grouped_genre

#Obtain averages of popularity, danceability, energy, loudness, tempo
avg_groups = grouped_genre.mean()

# %%
#Get data with loc
top_genres_data = avg_groups.loc[["Pop", "Rap", "Rock","Hip-Hop", "Indie", "Dance", "R&B", "Alternative"],
                                    ["popularity","danceability", "energy", "loudness","tempo"]]
#Display
top_genres_data
# Out:
#              popularity  danceability    energy  loudness       tempo
# genre
# Pop           66.590667      0.640236  0.642208 -6.495423  121.175844
# Rap           60.533795      0.697244  0.650520 -6.669916  121.100808
# Rock          59.619392      0.538292  0.683670 -7.285875  122.629630
# Hip-Hop       58.423131      0.718808  0.643275 -6.860286  120.791039
# Indie         54.701561      0.566821  0.581002 -7.915142  119.290814
# Dance         57.275256      0.638191  0.698067 -6.054241  120.795919
# R&B           52.308719      0.642125  0.564248 -7.597064  116.373834
# Alternative   50.213430      0.541898  0.711519 -6.540803  122.534485

# %%
#Generate and calculate 'partybility column'
partybility = top_genres_data["popularity"] + top_genres_data["danceability"] + top_genres_data["energy"] + top_genres_data["loudness"] + top_genres_data["tempo"]
top_genres_data["partybality"] = partybility

#display
top_genres_data
# Out:
#              popularity  danceability    energy  loudness       tempo  \
# genre
# Pop           66.590667      0.640236  0.642208 -6.495423  121.175844
# Rap           60.533795      0.697244  0.650520 -6.669916  121.100808
# Rock          59.619392      0.538292  0.683670 -7.285875  122.629630
# Hip-Hop       58.423131      0.718808  0.643275 -6.860286  120.791039
# Indie         54.701561      0.566821  0.581002 -7.915142  119.290814
# Dance         57.275256      0.638191  0.698067 -6.054241  120.795919
# R&B           52.308719      0.642125  0.564248 -7.597064  116.373834
# Alternative   50.213430      0.541898  0.711519 -6.540803  122.534485
#
#              partybality
# genre
# Pop           182.553533
# Rap           176.312452
# Rock          176.185108
# Hip-Hop       173.715966
# Indie         167.225056
# Dance         173.353191
# R&B           162.291862
# Alternative   167.460530

# %%
#Build popularity date frame

#Square popularity data to highlight the genre's differences
popularity_df = top_genres_data['popularity']**2
popularity_df = popularity_df.sort_values(ascending=False)
popularity_chart = popularity_df.plot(kind='bar', stacked=True, color='purple')

#Set the xlabel and ylabel using class methods
popularity_chart.set_xlabel("Genre")
popularity_chart.set_ylabel("Popularity Score")
popularity_chart.set_title("Genre Popularity")

#Save and display chart
plt.savefig("Output_Plots/Genre Popularity.png")
plt.show()
plt.tight_layout()

# %%
#Build danceability data frame

#Square danceability data to highlight the genre's differences
danceability_df = top_genres_data['danceability']**2
danceability_df = danceability_df.sort_values(ascending=False)
danceability_chart = danceability_df.plot(kind='bar', stacked=True, color='gold')

#Set the xlabel and ylabel using class methods
danceability_chart.set_xlabel("Genre")
danceability_chart.set_ylabel("Danceability Score")
danceability_chart.set_title("Genre Danceability")

#Save and display chart
plt.savefig("Output_Plots/Genre Danceability.png")
plt.show()
plt.tight_layout()

# %%
#Build energy data frame

#Square energy data to highlight the genre's differences
energy_df = top_genres_data['energy']**2
energy_df = energy_df.sort_values(ascending=False)
energy_chart = energy_df.plot(kind='bar', stacked=True, color='orange')

#Set the xlabel and ylabel using class methods
energy_chart.set_xlabel("Genre")
energy_chart.set_ylabel("Energy Score")
energy_chart.set_title("Genre Energy")

#Save and display chart
plt.savefig("Output_Plots/Genre Energy.png")
plt.show()
plt.tight_layout()

# %%
#Build loudness data frame

#Do not square value because loudness is in decibals
loudness_df = top_genres_data['loudness'].sort_values()
loudness_chart = loudness_df.plot(kind='bar', stacked=True, color='pink')

#Set the xlabel and ylabel using class methods
loudness_chart.set_xlabel("Genre")
loudness_chart.set_ylabel("Loudness (decibals)")
loudness_chart.set_title("Genre Loudness")

#Save and display chart
plt.savefig("Output_Plots/Genre Loudness.png")
plt.show()
plt.tight_layout()

# %%
#Build tempo data frame

#Do not square value because tempo is in BPM

tempo_df = top_genres_data['tempo'].sort_values(ascending = False) 
tempo_chart = tempo_df.plot(kind='bar', stacked=True, color='purple')

# Set the xlabel and ylabel using class methods
tempo_chart.set_xlabel("Genre")
tempo_chart.set_ylabel("Tempo (BPM)")
tempo_chart.set_title("Genre Tempo")

plt.savefig("Output_Plots/Genre Tempo.png")
plt.show()
plt.tight_layout()
tempo_df
# Out:
# genre
# Rock           122.629630
# Alternative    122.534485
# Pop            121.175844
# Rap            121.100808
# Dance          120.795919
# Hip-Hop        120.791039
# Indie          119.290814
# R&B            116.373834
# Name: tempo, dtype: float64

# %%
#Build partybility data frame
#Divide by 10 and square the partybality values to highlight the difference. 
partybality_df = top_genres_data['partybality']/10
partybality_adjusted = partybality_df**2
partybality_adjusted = partybality_adjusted.sort_values(ascending = False) 
partybality_chart = partybality_adjusted.plot(kind='bar', stacked=True, color='green')

#Set the xlabel and ylabel using class methods
partybality_chart.set_xlabel("Genre")
partybality_chart.set_ylabel("Partybility Score")
partybality_chart.set_title("Genre Partybility")

#Save and display chart
plt.savefig("Output_Plots/Genre Partybility.png")
plt.show()
plt.tight_layout()
